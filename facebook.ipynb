# %%
import pandas as pd

# %%
df = pd.read_csv("Facebook.csv", sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df = pd.read_csv("Facebook.csv", sep=';')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # 1. MAKING SUBSETS OF DATA ( ROW WISE )

# %%
df_subset = df[['Page total likes', 'Type', 'Category']]
df_subset
# Out:
#      Page total likes    Type  Category
# 0              139441   Photo         2
# 1              139441  Status         2
# 2              139441   Photo         3
# 3              139441   Photo         2
# 4              139441   Photo         2
# ..                ...     ...       ...
# 495             85093   Photo         3
# 496             81370   Photo         2
# 497             81370   Photo         1
# 498             81370   Photo         3
# 499             81370   Photo         2
#
# [500 rows x 3 columns]

# %%
df1 = df.iloc[:100, :]
df1.shape
# df1
# Out:
# (100, 19)

# %%
df2 = df.iloc[400:, :]
df2.shape
# df2
# Out:
# (100, 19)

# %%
df3 = df.iloc[401:426, :]
df3.shape
# df3
# Out:
# (25, 19)

# %%
df_merge = pd.merge(df2, df3, how='inner')   
df_merge.shape

#  inner :- intersection 
#  outer :- union
# Out:
# (25, 19)

# %%
df_concat = pd.concat([df1, df2])
# df_concat

# byDefault axis is 0 --> which is horizontal-wise
# axis = 1 --> which is horizontal-wise

# %% [markdown]
# # 2. MAKING SUBSETS OF DATA ( ROW WISE )

# %%
df6 = df.iloc[:, :5]
df6.shape
# Out:
# (500, 5)

# %%
df7 = df.iloc[:, 5:10]
df7.shape
# Out:
# (500, 5)

# %%
# df_merge_col = pd.merge(df6, df7, how='inner')
# df_merge_col

# %%
df_col_concat = pd.concat([df6, df7], axis=1)
# df_col_concat

# %% [markdown]
# # 3. SORTING THE VALUES

# %%
df_sort_asc = df.sort_values('Post Month', ascending=True)
# df_sort_asc

# %%
df_sort_des = df.sort_values('Post Month', ascending=False)
# df_sort_des

# %% [markdown]
# # 4. TRANSPOSING THE DATA

# %%
df_trans = df.transpose()
# df_trans

# %% [markdown]
# # 5. RESHAPING THE DATA

# %%
df_pivot = pd.pivot_table(df, index=['Type','Category'], values=['comment', 'like'], aggfunc='mean')
df_pivot
# Out:
#                    comment        like
# Type   Category
# Link   1          2.900000   75.650000
#        2          2.000000   32.000000
#        3          2.000000   68.000000
# Photo  1          5.897297  126.000000
#        2         11.692308  235.857143
#        3          6.913333  219.753333
# Status 1          4.333333  136.333333
#        2          9.921053  182.552632
#        3          2.750000  151.500000
# Video  1         12.285714  231.428571
